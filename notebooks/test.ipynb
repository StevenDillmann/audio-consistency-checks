# %%
from datasets import load_dataset
from huggingface_hub import InferenceClient
import random

ds = load_dataset("SALT-NLP/NormBank")["train"].filter(lambda x: x["norm"] != "taboo")

print(ds.column_names)
print(ds['setting'])

# get random sample from
settings = ds['setting']

# get random sample from settings
setting_example = random.choice(settings)
print(setting_example)

# get random sample from behavior
# Out:
# ['setting', 'behavior', 'setting-behavior', 'constraints', 'constraints_given', 'constraint_predict', 'norm', 'label', 'split']
# ...

# %%
# Out:
# ['banquet hall', 'running track', 'waterfall', 'campus', 'doctors office', 'drugstore', 'pool', 'airplane', 'airplane cabin', 'golf course', 'country road', 'basement', 'art gallery', 'boxing hall', 'cafe', 'bedroom', 'darkroom', 'campus', 'dentists office', 'beach', 'hotel room', 'bedroom', 'nursery', 'dentists office', 'athletic field', 'casino', 'casino', 'church or chapel', 'cemetery', 'gym', 'attic', 'white house', 'arcade', 'athletic field', 'grocery store', 'campus', 'amusement park', 'camera shop', 'bar', 'athletic field', 'monument', 'crime scene', 'taxi', 'post office', 'attic', 'drugstore', 'art gallery', 'childs room', 'copy center', 'jail or prison', 'hotel room', 'hospital', 'bathroom', 'clothing store', 'government office', 'alcoholics ward', 'ski resort', 'backyard', 'drugstore', 'animal shelter', 'grocery store', 'beach', 'attic', 'farm', 'bowling alley', 'kindergarden', 'kindergarden', 'courthouse', 'bedroom', 'hotel room', 'monument', 'golf course', 'boat', 'car', 
# ...
